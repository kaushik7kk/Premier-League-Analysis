# %% [markdown]
# # Premier League Analysis
# <br><br>

# %% [markdown]
# ![](https://pbs.twimg.com/media/EkDX0iOXYAAquOl.jpg)

# %% [markdown]
# <br>

# %% [markdown]
# The Premier League is the highest tiered football league in the English football league system. 20 clubs contest in the league and the team on the top of the standings at the end of the season is declared as the winner of the Premier League.
# <br><br>
# The top 4 teams play in the [UEFA Champions League](https://en.wikipedia.org/wiki/UEFA_Champions_League), 2 teams below the top 4 play in the [UEFA Europa League](https://en.wikipedia.org/wiki/UEFA_Europa_League) and the team below them plays the Conference League.
# <br><br>
# The bottom 3 teams in the table are relegated to the EFL Championship which is the lower tier of the English football league system.
# <br><br>
# Each team plays 38 matches in total, twice against each of the rest of the teams throughout the season.

# %% [markdown]
# <br><br>

# %% [markdown]
# This project features dataset involving stats for individual fixtures as well as full season stats for individual teams in the Premier League since the season '2006/07' and till the season '2017/18'.

# %% [markdown]
# For the data described above, there are two datasets I found on Kaggle that I'll be using for the project.

# %% [markdown]
# ## The Data

# %% [markdown]
# >### Data 1

# %% [markdown]
# >>[Data Link](https://www.kaggle.com/datasets/zaeemnalla/premier-league?select=results.csv)
# <br> <br>
# The first dataset we have been provided with is the one that shows all the game results for the fixtures during the period of seasons 2006/07 till 2017/18. This data can be easily tweaked and converted into a more compact form.

# %% [markdown]
# >>#### Data Description
# <br><br>
# >>>**Data Dimensions:**
# >>>- **Rows**- 4560
# >>>- **Columns**- 6

# %% [markdown]
# >>>**Columns:**
# <br>
# >>>- **home_team** - The home team involved in that particular fixture.
# >>>- **away_team** - The visiting team involved in the fixture.
# >>>- **home_goals** - The number of goals the home team scored.
# >>>- **away_goals** - The number of goals the visiting team scored.
# >>>- **result** - The result of the particular fixture(in discrete values like D(Draw), H(Home Team), A(Visiting Team)).
# >>>- **season** - The season in which the fixture was organized.

# %% [markdown]
# >### Data 2

# %% [markdown]
# >> [Data Link](https://www.kaggle.com/datasets/zaeemnalla/premier-league?select=stats.csv)
# <br><br>
# The second dataset among the two gives super detailed stats for each team in each different season. Although, the second dataset is more compact as compared to the first one, but still it provides more info compared to the first one because of a higher number of attributes.

# %% [markdown]
# >>#### Data Description
# <br><br>
# >>>**Data Dimensions:**
# <br>
# >>>- **Rows** - 240
# >>>- **Columns** - 42

# %% [markdown]
# >>>**Columns:**
# >>>- **team** - The team which the other attributes show stats for.
# >>>- **wins** - Number of wins the team had in that particular season.
# >>>- **losses** - Number of losses the team had in that particular season.
# >>>- **goals** - The number of goals the team scored in that particular season.
# >>>- **total_yel_card** - The number of yellow cards generated against the team in that season.
# >>>- **total_red_card** - The number of red cards generated against the team in that season.
# >>>- **total_scoring_att** - The total number of shots taken by the team during attacking.
# >>>- **ontarget_scoring_att** - The total number of shots hit on target by the team.
# >>>- **hit_woodwork** - The total number of shots that hit the woodwork (goal post).
# >>>- **att_hd_goal** - The number of goals scored using headers.
# >>>- **att_pen_goal** - The number of goals scored from penalties.
# >>>- **att_freekick_goal** - The number of goals scored from free kicks.
# >>>- **att_ibox_goal** - The number of goals scored by players standing inside the box at time of contact.
# >>>- **att_obox_goal** - The number of goals scored by players standing outside the box at time of contact.
# >>>- **goal_fastbreak** - The number of goals scored from counter attacks.
# >>>- **total_offside** - The number of offside fouls conceded by the team.
# >>>- **clean_sheet** - The number of clean sheets(no goals conceded during a macth) the team had.
# >>>- **goals_conceded** - The total number of goals conceded during the season.
# >>>- **saves** - The number of succesful saves by the team (goalkeepers).
# >>>- **outfielder_block** - The number of shots blocked by defenders before reaching the goal or the goalkeeper.
# >>>- **interception** - The number of succesful interceptions by players against opponent passes.
# >>>- **total_tackle** - The number of tackles put in by the players of the team.
# >>>- **last_man_tackle** - The number of times defenders fouled the opponent attacker being the last man defending.
# >>>- **total_clearance** - The number of clearances made by defenders against attacks.
# >>>- **head_clearance** - The number of headed clearances by the defenders.
# >>>- **own_goals** - The number of own goals scored by the players of the team.
# >>>- **penalty_conceded** - The number of penalties conceded by the team.
# >>>- **pen_goals_conceded** - The number of goals conceded from penalties.
# >>>- **total_pass** - The total number of passes made throughout the season.
# >>>- **total_through_ball** - The total number of through balls made by the team.
# >>>- **total_long_balls** - Total long ball passes made by the team.
# >>>- **backward_pass** - The number of backward passes(back to GK) made by the team.
# >>>- **total_cross** - The total number of crosses put in by the team.
# >>>- **corner_taken** - The number of corners taken by the team.
# >>>- **touches** - Total touches made with the ball by the players of the team.
# >>>- **big_chance_missed** - Number of big chances missed by the players.
# >>>- **clearance_off_line** - Number of clearances made off the goal line.
# >>>- **dispossessed** -  The number of times the team was dispossessed by the opponent team.
# >>>- **penalty_save** - The number of penalties saved by the team.
# >>>- **total_high_claim** - Number of high claims by the goalkeepers.
# >>>- **punches** - The number of punchaways to the balls by the goalkeepers.
# >>>- **season** - This is the actual column that specifies the season the rest of the info is about.

# %% [markdown]
# ### Importing Required Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# <br>

# %% [markdown]
# ### Data Cleaning

# %% [markdown]
# We'll be cleaning the datasets one by one.

# %%
results = pd.read_csv('results.csv')
results
# Out:
#               home_team         away_team  home_goals  away_goals result  \
# 0      Sheffield United         Liverpool         1.0         1.0      D
# 1               Arsenal       Aston Villa         1.0         1.0      D
# 2               Everton           Watford         2.0         1.0      H
# 3      Newcastle United    Wigan Athletic         2.0         1.0      H
# 4            Portsmouth  Blackburn Rovers         3.0         0.0      H
# ...                 ...               ...         ...         ...    ...
# 4555   Newcastle United           Chelsea         3.0         0.0      H
# 4556        Southampton   Manchester City         0.0         1.0      A
# 4557       Swansea City        Stoke City         1.0         2.0      A
# 4558  Tottenham Hotspur    Leicester City         5.0         4.0      H
# 4559    West Ham United           Everton         3.0         1.0      H
#
#          season
# 0     2006-2007
# 1     2006-2007
# 2     2006-2007
# 3     2006-2007
# 4     2006-2007
# ...         ...
# 4555  2017-2018
# 4556  2017-2018
# 4557  2017-2018
# 4558  2017-2018
# 4559  2017-2018
#
# [4560 rows x 6 columns]

# %%
pd.isnull(results).sum()
# Out:
# home_team     0
# away_team     0
# home_goals    0
# away_goals    0
# result        0
# season        0
# dtype: int64

# %% [markdown]
# No generic null values in the first dataset.

# %%
results.duplicated().sum()
# Out:
# 0

# %% [markdown]
# No duplicate results as well.

# %% [markdown]
# As these are results of individual fixtures, there can't be any outliers. The only outlier factors will be score differences but those can't be treated as outliers.

# %% [markdown]
# Moving on the second dataset.

# %%
stats = pd.read_csv('stats.csv')
stats
# Out:
#                      team  wins  losses  goals  total_yel_card  \
# 0       Manchester United  28.0     5.0   83.0            60.0
# 1                 Chelsea  24.0     3.0   64.0            62.0
# 2               Liverpool  20.0    10.0   57.0            44.0
# 3                 Arsenal  19.0     8.0   63.0            59.0
# 4       Tottenham Hotspur  17.0    12.0   57.0            48.0
# ..                    ...   ...     ...    ...             ...
# 235     Huddersfield Town   9.0    19.0   28.0            62.0
# 236          Swansea City   8.0    21.0   28.0            51.0
# 237           Southampton   7.0    16.0   37.0            63.0
# 238            Stoke City   7.0    19.0   35.0            62.0
# 239  West Bromwich Albion   6.0    19.0   31.0            73.0
#
#      total_red_card  total_scoring_att  ontarget_scoring_att  hit_woodwork  \
# 0               1.0              698.0                 256.0          21.0
# 1               4.0              636.0                 216.0          14.0
# 2               0.0              668.0                 214.0          15.0
# 3               3.0              638.0                 226.0          19.0
# 4               3.0              520.0                 184.0           6.0
# ..              ...                ...                   ...           ...
# 235             3.0              362.0                 109.0           8.0
# 236             1.0              338.0                 103.0           8.0
# 237             2.0              450.0                 145.0          15.0
# 238             1.0              384.0                 132.0           8.0
# 239             1.0              378.0                 114.0           7.0
#
#      att_hd_goal  ...  total_cross  corner_taken  touches  big_chance_missed  \
# 0           12.0  ...        918.0         258.0  25686.0                NaN
# 1           16.0  ...        897.0         231.0  24010.0                NaN
# 2            8.0  ...       1107.0         282.0  24150.0                NaN
# 3           10.0  ...        873.0         278.0  25592.0                NaN
# 4            5.0  ...        796.0         181.0  22200.0                NaN
# ..           ...  ...          ...           ...      ...                ...
# 235          5.0  ...        765.0         165.0  22619.0               21.0
# 236          3.0  ...        694.0         150.0  22775.0               26.0
# 237          7.0  ...        800.0         227.0  24639.0               37.0
# 238          8.0  ...        598.0         136.0  20368.0               33.0
# 239         10.0  ...        784.0         176.0  20552.0               28.0
#
#      clearance_off_line  dispossessed  penalty_save  total_high_claim  \
# 0                   1.0           NaN           2.0              37.0
# 1                   2.0           NaN           1.0              74.0
# 2                   1.0           NaN           0.0              51.0
# 3                   1.0           NaN           0.0              88.0
# 4                   2.0           NaN           0.0              51.0
# ..                  ...           ...           ...               ...
# 235                 6.0         416.0           2.0              31.0
# 236                 1.0         439.0           3.0              44.0
# 237                 4.0         379.0           1.0              29.0
# 238                 3.0         402.0           0.0              27.0
# 239                 3.0         446.0           0.0              40.0
#
#      punches     season
# 0       25.0  2006-2007
# 1       22.0  2006-2007
# 2       27.0  2006-2007
# 3       27.0  2006-2007
# 4       24.0  2006-2007
# ..       ...        ...
# 235     24.0  2017-2018
# 236     15.0  2017-2018
# 237     13.0  2017-2018
# 238     14.0  2017-2018
# 239      5.0  2017-2018
#
# [240 rows x 42 columns]

# %%
stats.isnull().sum()
# Out:
# team                     0
# wins                     0
# losses                   0
# goals                    0
# total_yel_card           0
# total_red_card           0
# total_scoring_att        0
# ontarget_scoring_att     0
# hit_woodwork             0
# att_hd_goal              0
# att_pen_goal             0
# att_freekick_goal        0
# att_ibox_goal            0
# att_obox_goal            0
# goal_fastbreak           0
# total_offside            0
# clean_sheet              0
# goals_conceded           0
# saves                   20
# outfielder_block         0
# interception             0
# total_tackle             0
# last_man_tackle          0
# total_clearance          0
# head_clearance          20
# own_goals                0
# penalty_conceded         0
# pen_goals_conceded       0
# total_pass               0
# total_through_ball      20
# total_long_balls         0
# backward_pass           80
# total_cross              0
# corner_taken             0
# touches                  0
# big_chance_missed       80
# clearance_off_line       0
# dispossessed            20
# penalty_save             0
# total_high_claim         0
# punches                  0
# season                   0
# dtype: int64

# %% [markdown]
# As we can see, there are numerous null values in the second dataset.

# %%
stats[stats.backward_pass.isnull()][['saves', 'head_clearance', 'total_through_ball', 'backward_pass', 'big_chance_missed', 'dispossessed']]
# Out:
#     saves  head_clearance  total_through_ball  backward_pass  \
# 0     2.0             NaN                 NaN            NaN
# 1     4.0             NaN                 NaN            NaN
# 2     1.0             NaN                 NaN            NaN
# 3     6.0             NaN                 NaN            NaN
# 4    11.0             NaN                 NaN            NaN
# ..    ...             ...                 ...            ...
# 75    0.0           784.0                60.0            NaN
# 76    0.0           775.0                83.0            NaN
# 77    4.0           870.0               164.0            NaN
# 78    0.0           751.0                95.0            NaN
# 79    0.0           805.0                46.0            NaN
#
#     big_chance_missed  dispossessed
# 0                 NaN           NaN
# 1                 NaN           NaN
# 2                 NaN           NaN
# 3                 NaN           NaN
# 4                 NaN           NaN
# ..                ...           ...
# 75                NaN         410.0
# 76                NaN         524.0
# 77                NaN         522.0
# 78                NaN         497.0
# 79                NaN         535.0
#
# [80 rows x 6 columns]

# %% [markdown]
# So, not all the null values occur simultaneously in all the columns.

# %% [markdown]
# The crucial attributes out of the ones having null values will be:
# <br><br>
# - saves
# - big_chances_missed
# <br>

# %% [markdown]
# The ones that can be ignored or won't be as crucial in the analysis are:
# <br><br>
# - head_clearance
# - total_through_ball
# - backward_pass
# - dispossessed

# %% [markdown]
# The column named 'big_chances_missed' has a lot of null values and won't be as accurate and able to provide the correct figures for all the individual teams. At the same time, these values can't be predicted or calculated using other teams' values.
# <br><br>
# The two options for this will be either to drop the column or use this in analysing the data for the team for which the data is available at all or for all seasons.

# %% [markdown]
# ---
# <br>
# Let's start working on the first dataset.

# %% [markdown]
# <br>

# %%
results.head(10)
# Out:
#            home_team          away_team  home_goals  away_goals result  \
# 0   Sheffield United          Liverpool         1.0         1.0      D
# 1            Arsenal        Aston Villa         1.0         1.0      D
# 2            Everton            Watford         2.0         1.0      H
# 3   Newcastle United     Wigan Athletic         2.0         1.0      H
# 4         Portsmouth   Blackburn Rovers         3.0         0.0      H
# 5            Reading      Middlesbrough         3.0         2.0      H
# 6    West Ham United  Charlton Athletic         3.0         1.0      H
# 7   Bolton Wanderers  Tottenham Hotspur         2.0         0.0      H
# 8  Manchester United             Fulham         5.0         1.0      H
# 9            Chelsea    Manchester City         3.0         0.0      H
#
#       season
# 0  2006-2007
# 1  2006-2007
# 2  2006-2007
# 3  2006-2007
# 4  2006-2007
# 5  2006-2007
# 6  2006-2007
# 7  2006-2007
# 8  2006-2007
# 9  2006-2007

# %%
results.describe()
# Out:
#         home_goals   away_goals
# count  4560.000000  4560.000000
# mean      1.543202     1.144298
# std       1.315163     1.139824
# min       0.000000     0.000000
# 25%       1.000000     0.000000
# 50%       1.000000     1.000000
# 75%       2.000000     2.000000
# max       9.000000     7.000000

# %% [markdown]
# We'll make a standard format for the overall score of the match in a separate column.

# %%
results['home_goals'] = results.home_goals.apply(lambda x : int(x))
results['away_goals'] = results.away_goals.apply(lambda x : int(x))
results
# Out:
#               home_team         away_team  home_goals  away_goals result  \
# 0      Sheffield United         Liverpool           1           1      D
# 1               Arsenal       Aston Villa           1           1      D
# 2               Everton           Watford           2           1      H
# 3      Newcastle United    Wigan Athletic           2           1      H
# 4            Portsmouth  Blackburn Rovers           3           0      H
# ...                 ...               ...         ...         ...    ...
# 4555   Newcastle United           Chelsea           3           0      H
# 4556        Southampton   Manchester City           0           1      A
# 4557       Swansea City        Stoke City           1           2      A
# 4558  Tottenham Hotspur    Leicester City           5           4      H
# 4559    West Ham United           Everton           3           1      H
#
#          season
# 0     2006-2007
# 1     2006-2007
# 2     2006-2007
# 3     2006-2007
# 4     2006-2007
# ...         ...
# 4555  2017-2018
# 4556  2017-2018
# 4557  2017-2018
# 4558  2017-2018
# 4559  2017-2018
#
# [4560 rows x 6 columns]

# %%
for i in results.index:
    results.loc[i, 'score'] = f"{results.loc[i, ('home_team')]}  {results.loc[i, ('home_goals')]} - {results.loc[i, ('away_goals')]}  {results.loc[i, ('away_team')]}"
results
# Out:
#               home_team         away_team  home_goals  away_goals result  \
# 0      Sheffield United         Liverpool           1           1      D
# 1               Arsenal       Aston Villa           1           1      D
# 2               Everton           Watford           2           1      H
# 3      Newcastle United    Wigan Athletic           2           1      H
# 4            Portsmouth  Blackburn Rovers           3           0      H
# ...                 ...               ...         ...         ...    ...
# 4555   Newcastle United           Chelsea           3           0      H
# 4556        Southampton   Manchester City           0           1      A
# 4557       Swansea City        Stoke City           1           2      A
# 4558  Tottenham Hotspur    Leicester City           5           4      H
# 4559    West Ham United           Everton           3           1      H
#
#          season                                     score
# 0     2006-2007        Sheffield United  1 - 1  Liverpool
# 1     2006-2007               Arsenal  1 - 1  Aston Villa
# 2     2006-2007                   Everton  2 - 1  Watford
# 3     2006-2007   Newcastle United  2 - 1  Wigan Athletic
# 4     2006-2007       Portsmouth  3 - 0  Blackburn Rovers
# ...         ...                                       ...
# 4555  2017-2018          Newcastle United  3 - 0  Chelsea
# 4556  2017-2018       Southampton  0 - 1  Manchester City
# 4557  2017-2018           Swansea City  1 - 2  Stoke City
# 4558  2017-2018  Tottenham Hotspur  5 - 4  Leicester City
# 4559  2017-2018           West Ham United  3 - 1  Everton
#
# [4560 rows x 7 columns]

# %% [markdown]
# Let's find out the highest goal scoring match in all the provided seasons.

# %%
results['goals'] = results['home_goals'].apply(lambda x: x)
results['goals'] += results['away_goals'].apply(lambda x: x)
results
# Out:
#               home_team         away_team  home_goals  away_goals result  \
# 0      Sheffield United         Liverpool           1           1      D
# 1               Arsenal       Aston Villa           1           1      D
# 2               Everton           Watford           2           1      H
# 3      Newcastle United    Wigan Athletic           2           1      H
# 4            Portsmouth  Blackburn Rovers           3           0      H
# ...                 ...               ...         ...         ...    ...
# 4555   Newcastle United           Chelsea           3           0      H
# 4556        Southampton   Manchester City           0           1      A
# 4557       Swansea City        Stoke City           1           2      A
# 4558  Tottenham Hotspur    Leicester City           5           4      H
# 4559    West Ham United           Everton           3           1      H
#
#          season                                     score  goals
# 0     2006-2007        Sheffield United  1 - 1  Liverpool      2
# 1     2006-2007               Arsenal  1 - 1  Aston Villa      2
# 2     2006-2007                   Everton  2 - 1  Watford      3
# 3     2006-2007   Newcastle United  2 - 1  Wigan Athletic      3
# 4     2006-2007       Portsmouth  3 - 0  Blackburn Rovers      3
# ...         ...                                       ...    ...
# 4555  2017-2018          Newcastle United  3 - 0  Chelsea      3
# 4556  2017-2018       Southampton  0 - 1  Manchester City      1
# 4557  2017-2018           Swansea City  1 - 2  Stoke City      3
# 4558  2017-2018  Tottenham Hotspur  5 - 4  Leicester City      9
# 4559  2017-2018           West Ham United  3 - 1  Everton      4
#
# [4560 rows x 8 columns]

# %%
maxGoals = results.goals.idxmax()
print(f"The fixture with the highest number of goals scored is {results.loc[maxGoals, ('home_team')]} vs {results.loc[maxGoals, ('away_team')]} in the season {results.loc[maxGoals, ('season')]} with {results.loc[maxGoals, ('goals')]} goals in total.")
# Out:
# The fixture with the highest number of goals scored is Portsmouth vs Reading in the season 2007-2008 with 11 goals in total.

# %% [markdown]
# Let's frame some analysis questions for this dataset.

# %% [markdown]
# ### Q. Which are the top-10 most succesful teams over the seasons?

# %%
for i in results.index:
    results.loc[i, 'winner'] = results.loc[i, 'home_team'] if (results.loc[i, 'result'] == 'H') else results.loc[i, 'away_team']
results
# Out:
#               home_team         away_team  home_goals  away_goals result  \
# 0      Sheffield United         Liverpool           1           1      D
# 1               Arsenal       Aston Villa           1           1      D
# 2               Everton           Watford           2           1      H
# 3      Newcastle United    Wigan Athletic           2           1      H
# 4            Portsmouth  Blackburn Rovers           3           0      H
# ...                 ...               ...         ...         ...    ...
# 4555   Newcastle United           Chelsea           3           0      H
# 4556        Southampton   Manchester City           0           1      A
# 4557       Swansea City        Stoke City           1           2      A
# 4558  Tottenham Hotspur    Leicester City           5           4      H
# 4559    West Ham United           Everton           3           1      H
#
#          season                                     score  goals  \
# 0     2006-2007        Sheffield United  1 - 1  Liverpool      2
# 1     2006-2007               Arsenal  1 - 1  Aston Villa      2
# 2     2006-2007                   Everton  2 - 1  Watford      3
# 3     2006-2007   Newcastle United  2 - 1  Wigan Athletic      3
# 4     2006-2007       Portsmouth  3 - 0  Blackburn Rovers      3
# ...         ...                                       ...    ...
# 4555  2017-2018          Newcastle United  3 - 0  Chelsea      3
# 4556  2017-2018       Southampton  0 - 1  Manchester City      1
# 4557  2017-2018           Swansea City  1 - 2  Stoke City      3
# 4558  2017-2018  Tottenham Hotspur  5 - 4  Leicester City      9
# 4559  2017-2018           West Ham United  3 - 1  Everton      4
#
#                  winner
# 0             Liverpool
# 1           Aston Villa
# 2               Everton
# 3      Newcastle United
# 4            Portsmouth
# ...                 ...
# 4555   Newcastle United
# 4556    Manchester City
# 4557         Stoke City
# 4558  Tottenham Hotspur
# 4559    West Ham United
#
# [4560 rows x 9 columns]

# %%
winCount = results.groupby(['winner'])[['winner']].count().rename(columns = {'winner' : 'No. of Wins'})
winCount.index.names = ['Team']
winCount.sort_values(by = 'No. of Wins', ascending = False).head(10)
# Out:
#                    No. of Wins
# Team
# Manchester United          348
# Chelsea                    325
# Manchester City            312
# Arsenal                    312
# Tottenham Hotspur          290
# Liverpool                  288
# Everton                    267
# West Ham United            186
# Stoke City                 171
# Aston Villa                169

# %% [markdown]
# ### Q. Which of the teams played the least number of seasons during the given time period? <br><br> (Keeping in mind the relegation and promotion system of the English football league system)

# %%
results['season'].nunique()
# Out:
# 12

# %% [markdown]
# The data is about 12 seasons in total.
# <br>
# Let's find out how many seasons did each team play.

# %%
results[['home_team', 'season']].drop_duplicates().groupby(['home_team'])[['season']].count().sort_values(by = 'season')
# Out:
#                           season
# home_team
# Sheffield United               1
# Huddersfield Town              1
# Blackpool                      1
# Derby County                   1
# Brighton and Hove Albion       1
# Charlton Athletic              1
# Cardiff City                   1
# AFC Bournemouth                3
# Reading                        3
# Queens Park Rangers            3
# Wolverhampton Wanderers        3
# Birmingham City                3
# Norwich City                   4
# Portsmouth                     4
# Burnley                        4
# Middlesbrough                  4
# Leicester City                 4
# Watford                        4
# Crystal Palace                 5
# Hull City                      5
# Blackburn Rovers               6
# Bolton Wanderers               6
# Southampton                    6
# Wigan Athletic                 7
# Swansea City                   7
# Fulham                         8
# West Bromwich Albion           9
# Sunderland                    10
# Newcastle United              10
# Aston Villa                   10
# Stoke City                    10
# West Ham United               11
# Tottenham Hotspur             12
# Chelsea                       12
# Manchester United             12
# Manchester City               12
# Everton                       12
# Arsenal                       12
# Liverpool                     12

# %% [markdown]
# As this is a fixture-by-fixture based dataset, most of the aggregated analysis or representation of the data involves actual calculation for the output.
# <br><br>
# On the other hand, the second dataset has a lot of attributes but such representations will be much easier when we'll work on that.

# %% [markdown]
# Let's try working on making a points table for the teams for each season.

# %% [markdown]
# **Let's explain the criterion for points first.**
# <br>
# - **Win** - 3 points
# - **Loss** - 0 points
# - **Draw** - 1 point

# %% [markdown]
# **If any conflicts occur in terms of points in the table, other factors are used to decide the standings for the teams.**
#
# - **Goal Difference** - The team with higher goal difference is given the higher spot.
# - **Goals Scored** - If the GD is also the same, the team with more goals scored so far is given the higher spot.
# - **Goals per game** - If even the second factor can't split two teams, the team with high number of goals per game is preferred for the better spot.
# - **Head-to-head points** - Further, the team with more points against the tie-breaking team is preferred.
# - **Head-to-head away goals** - Then, the team which scored more goals on the other team's stadium is preferred.
# - **Play-off** - If none of the above factors can split the two teams, a separate play-off match at a neutral venue is played between the two teams for the winner. (Only in case of the title winner)

# %% [markdown]
# Let's make a rough points table using the first dataset for just the points ignoring the rest of the factors for the standings.

# %% [markdown]
# We'll make an actual points table with all the factors in mind in a separate notebook and compare both the tables if they differ much.

# %%
points_data = results.copy()
points_data
# Out:
#               home_team         away_team  home_goals  away_goals result  \
# 0      Sheffield United         Liverpool           1           1      D
# 1               Arsenal       Aston Villa           1           1      D
# 2               Everton           Watford           2           1      H
# 3      Newcastle United    Wigan Athletic           2           1      H
# 4            Portsmouth  Blackburn Rovers           3           0      H
# ...                 ...               ...         ...         ...    ...
# 4555   Newcastle United           Chelsea           3           0      H
# 4556        Southampton   Manchester City           0           1      A
# 4557       Swansea City        Stoke City           1           2      A
# 4558  Tottenham Hotspur    Leicester City           5           4      H
# 4559    West Ham United           Everton           3           1      H
#
#          season                                     score  goals  \
# 0     2006-2007        Sheffield United  1 - 1  Liverpool      2
# 1     2006-2007               Arsenal  1 - 1  Aston Villa      2
# 2     2006-2007                   Everton  2 - 1  Watford      3
# 3     2006-2007   Newcastle United  2 - 1  Wigan Athletic      3
# 4     2006-2007       Portsmouth  3 - 0  Blackburn Rovers      3
# ...         ...                                       ...    ...
# 4555  2017-2018          Newcastle United  3 - 0  Chelsea      3
# 4556  2017-2018       Southampton  0 - 1  Manchester City      1
# 4557  2017-2018           Swansea City  1 - 2  Stoke City      3
# 4558  2017-2018  Tottenham Hotspur  5 - 4  Leicester City      9
# 4559  2017-2018           West Ham United  3 - 1  Everton      4
#
#                  winner
# 0             Liverpool
# 1           Aston Villa
# 2               Everton
# 3      Newcastle United
# 4            Portsmouth
# ...                 ...
# 4555   Newcastle United
# 4556    Manchester City
# 4557         Stoke City
# 4558  Tottenham Hotspur
# 4559    West Ham United
#
# [4560 rows x 9 columns]

# %% [markdown]
# Let's find the points for the teams using dictionaries as data structures.

# %%
points = dict()
for season in pd.unique(results['season']):
    points[season] = dict()
    currSeason = points[season]
    for index, record in results[results['season'] == season].iterrows():
        if record.result == 'H':
            currSeason[record.home_team] = currSeason.get(record.home_team, 0) + 3
        elif record.result == 'A':
            currSeason[record.away_team] = currSeason.get(record.away_team, 0) + 3
        else:
            currSeason[record.home_team] = currSeason.get(record.home_team, 0) + 1
            currSeason[record.away_team] = currSeason.get(record.away_team, 0) + 1

# %%
pTable = pd.DataFrame(points)
pTable
# Out:
#                           2006-2007  2007-2008  2008-2009  2009-2010  \
# Sheffield United               38.0        NaN        NaN        NaN
# Liverpool                      68.0       76.0       86.0       63.0
# Arsenal                        68.0       83.0       72.0       75.0
# Aston Villa                    50.0       60.0       62.0       64.0
# Everton                        58.0       65.0       63.0       61.0
# Newcastle United               43.0       43.0       34.0        NaN
# Portsmouth                     54.0       57.0       41.0       28.0
# Reading                        55.0       36.0        NaN        NaN
# West Ham United                41.0       49.0       51.0       35.0
# Bolton Wanderers               56.0       37.0       41.0       39.0
# Manchester United              89.0       87.0       90.0       85.0
# Chelsea                        83.0       85.0       83.0       86.0
# Watford                        28.0        NaN        NaN        NaN
# Tottenham Hotspur              60.0       46.0       51.0       70.0
# Manchester City                42.0       55.0       50.0       67.0
# Blackburn Rovers               52.0       58.0       41.0       50.0
# Fulham                         39.0       36.0       53.0       46.0
# Middlesbrough                  46.0       42.0       32.0        NaN
# Charlton Athletic              34.0        NaN        NaN        NaN
# Wigan Athletic                 38.0       40.0       45.0       36.0
# Sunderland                      NaN       39.0       36.0       44.0
# Derby County                    NaN       11.0        NaN        NaN
# Birmingham City                 NaN       35.0        NaN       50.0
# Hull City                       NaN        NaN       35.0       30.0
# Stoke City                      NaN        NaN       45.0       47.0
# West Bromwich Albion            NaN        NaN       32.0        NaN
# Wolverhampton Wanderers         NaN        NaN        NaN       38.0
# Burnley                         NaN        NaN        NaN       30.0
# Blackpool                       NaN        NaN        NaN        NaN
# Norwich City                    NaN        NaN        NaN        NaN
# Queens Park Rangers             NaN        NaN        NaN        NaN
# Swansea City                    NaN        NaN        NaN        NaN
# Southampton                     NaN        NaN        NaN        NaN
# Cardiff City                    NaN        NaN        NaN        NaN
# Crystal Palace                  NaN        NaN        NaN        NaN
# Leicester City                  NaN        NaN        NaN        NaN
# AFC Bournemouth                 NaN        NaN        NaN        NaN
# Huddersfield Town               NaN        NaN        NaN        NaN
# Brighton and Hove Albion        NaN        NaN        NaN        NaN
#
#                           2010-2011  2011-2012  2012-2013  2013-2014  \
# Sheffield United                NaN        NaN        NaN        NaN
# Liverpool                      58.0       52.0       61.0       84.0
# Arsenal                        68.0       70.0       73.0       79.0
# Aston Villa                    48.0       38.0       41.0       38.0
# Everton                        54.0       56.0       63.0       72.0
# Newcastle United               46.0       65.0       41.0       49.0
# Portsmouth                      NaN        NaN        NaN        NaN
# Reading                         NaN        NaN       28.0        NaN
# West Ham United                33.0        NaN       46.0       40.0
# Bolton Wanderers               46.0       36.0        NaN        NaN
# Manchester United              80.0       89.0       89.0       64.0
# Chelsea                        71.0       64.0       75.0       82.0
# Watford                         NaN        NaN        NaN        NaN
# Tottenham Hotspur              62.0       69.0       72.0       69.0
# Manchester City                71.0       89.0       78.0       86.0
# Blackburn Rovers               43.0       31.0        NaN        NaN
# Fulham                         49.0       52.0       43.0       32.0
# Middlesbrough                   NaN        NaN        NaN        NaN
# Charlton Athletic               NaN        NaN        NaN        NaN
# Wigan Athletic                 42.0       43.0       36.0        NaN
# Sunderland                     47.0       45.0       39.0       38.0
# Derby County                    NaN        NaN        NaN        NaN
# Birmingham City                39.0        NaN        NaN        NaN
# Hull City                       NaN        NaN        NaN       37.0
# Stoke City                     46.0       45.0       42.0       50.0
# West Bromwich Albion           47.0       47.0       49.0       36.0
# Wolverhampton Wanderers        40.0       25.0        NaN        NaN
# Burnley                         NaN        NaN        NaN        NaN
# Blackpool                      39.0        NaN        NaN        NaN
# Norwich City                    NaN       47.0       44.0       33.0
# Queens Park Rangers             NaN       37.0       25.0        NaN
# Swansea City                    NaN       47.0       46.0       42.0
# Southampton                     NaN        NaN       41.0       56.0
# Cardiff City                    NaN        NaN        NaN       30.0
# Crystal Palace                  NaN        NaN        NaN       45.0
# Leicester City                  NaN        NaN        NaN        NaN
# AFC Bournemouth                 NaN        NaN        NaN        NaN
# Huddersfield Town               NaN        NaN        NaN        NaN
# Brighton and Hove Albion        NaN        NaN        NaN        NaN
#
#                           2014-2015  2015-2016  2016-2017  2017-2018
# Sheffield United                NaN        NaN        NaN        NaN
# Liverpool                      62.0       60.0       76.0       75.0
# Arsenal                        75.0       71.0       75.0       63.0
# Aston Villa                    38.0       17.0        NaN        NaN
# Everton                        47.0       47.0       61.0       49.0
# Newcastle United               39.0       37.0        NaN       44.0
# Portsmouth                      NaN        NaN        NaN        NaN
# Reading                         NaN        NaN        NaN        NaN
# West Ham United                47.0       62.0       45.0       42.0
# Bolton Wanderers                NaN        NaN        NaN        NaN
# Manchester United              70.0       66.0       69.0       81.0
# Chelsea                        87.0       50.0       93.0       70.0
# Watford                         NaN       45.0       40.0       41.0
# Tottenham Hotspur              64.0       70.0       86.0       77.0
# Manchester City                79.0       66.0       78.0      100.0
# Blackburn Rovers                NaN        NaN        NaN        NaN
# Fulham                          NaN        NaN        NaN        NaN
# Middlesbrough                   NaN        NaN       28.0        NaN
# Charlton Athletic               NaN        NaN        NaN        NaN
# Wigan Athletic                  NaN        NaN        NaN        NaN
# Sunderland                     38.0       39.0       24.0        NaN
# Derby County                    NaN        NaN        NaN        NaN
# Birmingham City                 NaN        NaN        NaN        NaN
# Hull City                      35.0        NaN       34.0        NaN
# Stoke City                     54.0       51.0       44.0       33.0
# West Bromwich Albion           44.0       43.0       45.0       31.0
# Wolverhampton Wanderers         NaN        NaN        NaN        NaN
# Burnley                        33.0        NaN       40.0       54.0
# Blackpool                       NaN        NaN        NaN        NaN
# Norwich City                    NaN       34.0        NaN        NaN
# Queens Park Rangers            30.0        NaN        NaN        NaN
# Swansea City                   56.0       47.0       41.0       33.0
# Southampton                    60.0       63.0       46.0       36.0
# Cardiff City                    NaN        NaN        NaN        NaN
# Crystal Palace                 48.0       42.0       41.0       44.0
# Leicester City                 41.0       81.0       44.0       47.0
# AFC Bournemouth                 NaN       42.0       46.0       44.0
# Huddersfield Town               NaN        NaN        NaN       37.0
# Brighton and Hove Albion        NaN        NaN        NaN       40.0

# %% [markdown]
# The records where the value is NaN, the data shows that the team was relegated and didn't play that season in the Premier League.

# %%
plt.figure(figsize = (20, 20))
sns.heatmap(pTable, annot = True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Let's see how much the winner of any fixture was affected by the venue of the game (home & away).

# %%
results.groupby('result')[['result']].count().rename(columns = {'result' : 'count'})
# Out:
#         count
# result
# A        1288
# D        1164
# H        2108

# %% [markdown]
# As we can see, the number of wins in which the home team won the match is quite higher than the away winners.
# <br><br>
# Now, we'll see these stats for each individual team.
